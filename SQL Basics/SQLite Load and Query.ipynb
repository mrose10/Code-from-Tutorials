# %%
import sqlite3
import pandas as pd
import numpy as np

# %%
sqlite_file = r'C:\Users\molly\Documents\Python Scripts\test.db' #Point to the db

conn = sqlite3.connect(sqlite_file)

cursor = conn.cursor() #Cursor objects are the interface to the database

#conn.commit() #save change to database other than sending queries
#conn.close()

# %%
# Get a list of the tables saved in the database
for row in cursor.execute("SELECT name FROM sqlite_master WHERE type = 'table'"):
    print(row)
# Out:
# ('Fake2days',)

# %%
query = "SELECT Timestamp, `Fluorescence-Red`, PlantID FROM Fake2days WHERE Location = 'Greenhouse'"

# %%
table = pd.read_sql_query("SELECT * FROM Fake2days",conn)

# %%
table.head()
# Out:
#         Timestamp SensorID ExperimentID Vector    Constructoverview  \
# 0    4/17/20 3:00      WE1         E001    V14  AtVSP1:TdTomato-HSP
# 1  4/17/2020 3:15      WE1         E001    V14  AtVSP1:TdTomato-HSP
# 2    4/17/20 3:30      WE1         E001    V14  AtVSP1:TdTomato-HSP
# 3  4/17/2020 3:45      WE1         E001    V14  AtVSP1:TdTomato-HSP
# 4    4/17/20 4:00      WE1         E001    V14  AtVSP1:TdTomato-HSP
#
#   Fluorophore inducedby       Plant    Location  PlantID PlantAge/Maturity  \
# 0    Tdtomato    insect  Tomato M82  Greenhouse        1              None
# 1    Tdtomato    insect  Tomato M82  Greenhouse        1              None
# 2    Tdtomato    insect  Tomato M82  Greenhouse        1              None
# 3    Tdtomato    insect  Tomato M82  Greenhouse        1              None
# 4    Tdtomato    insect  Tomato M82  Greenhouse        1              None
#
#   Fluorescence-Green  Fluorescence-Red Temperature Humidity PlantSoilwater  \
# ...

# %%
green = pd.read_sql_query(query,conn)
green.head()
# Out:
#         Timestamp  Fluorescence-Red  PlantID
# 0    4/17/20 3:00          0.000045        1
# 1  4/17/2020 3:15          0.000051        1
# 2    4/17/20 3:30          0.000057        1
# 3  4/17/2020 3:45          0.000063        1
# 4    4/17/20 4:00          0.000071        1

# %%
import plotly.express as px

fig = px.scatter(green, x='Timestamp', y='Fluorescence-Red',color="PlantID")
fig.show()
# Out:
# <div>
#
#
#             <div id="3d4f8f72-737b-43b3-9c5c-07910abd5c83" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3d4f8f72-737b-43b3-9c5c-07910abd5c83")) {
#                     Plotly.newPlot(
#                         '3d4f8f72-737b-43b3-9c5c-07910abd5c83',
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(x=green.Timestamp, y=green['Fluorescence-Red'],
                    mode='markers',
                    name='Greenhouse'))
# Out:
# <div>
#
#
#             <div id="4f457ffb-510d-409c-9a81-617fcc6daddf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4f457ffb-510d-409c-9a81-617fcc6daddf")) {
#                     Plotly.newPlot(
#                         '4f457ffb-510d-409c-9a81-617fcc6daddf',
# ...
